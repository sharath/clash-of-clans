# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from clan import generate_clan

# %%
plt.style.use('seaborn-white')

# %%
clans = [generate_clan() for i in range(4)]
steps = 7000
dt = 700/steps 
x = np.linspace(0, 700, steps)

for t in x:
    for c in clans:
        c.step(dt)

# %%
len(np.add(c.history['m'],c.history['f']))
# Out:
# 7000

# %%
plt.gcf().set_size_inches(15, 10)
sns.despine()
plt.xlabel('Time')
plt.ylabel('Population')
for n, c in enumerate(clans):
    plt.plot(x, np.add(c.history['m'],c.history['f']), label=f'Clan {n+1}')
plt.legend()
plt.show()

# %%
from constants import total_k
total_k - np.sum([c.p for c in clans])
# Out:
# -393296.74003239535

# %%
plt.gcf().set_size_inches(15, 10)
sns.despine()
plt.xlabel('Time')
plt.ylabel('Ratio Female')
for n, c in enumerate(clans):
    plt.plot(x, c.history['s'], label=f'Clan {n+1}')
plt.legend()
plt.show()

# %%
plt.gcf().set_size_inches(15, 10)
sns.despine()
plt.xlabel('Time')
plt.ylabel('Radius')
for n, c in enumerate(clans):
    plt.plot(x, c.history['radius'], label=f'Clan {n+1}')
plt.legend()
plt.show()

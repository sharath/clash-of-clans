# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from clan import generate_clan

# %%
i = generate_clan()
j = generate_clan()

# %%
dt = 1
x = np.linspace(0, 7000, dt)
data = []
for t in range(int(7000/dt)):
    i.step(dt)
    j.step(dt)
# Out:
# 9036.132014692703
# 4947.171836489486
# 47910.133465001294
# 20913.06738413876
# 432331.5989659034
# 136797.85603494127
# 5404579.919692919
# 1634583.1289027024
# -2129566093.9088924
# -58590241.3515448
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
vars(i)
# Out:
# {'x': 99.71848109388685,
#  'y': 93.25573593386588,
#  'p': nan,
#  's': nan,
#  'K': 870000,
#  'delta': nan,
#  'r': nan}
